# %% [markdown]
# # Strings multiplas linhas (string triplas)

# %%
nome = "Bruno"

# %%
print(f"""
Meu nome é {nome},
  Estou aprendendo Python.
""")
# Out:
# Meu nome é Bruno,
#   Estou aprendendo Python.
