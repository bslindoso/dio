# %% [markdown]
# # Fatiamento de strings

# %%
nome = "Bruno Santos Lindoso"

# %%
nome[0]
# Out:
# 'B'

# %%
nome[-1]
# Out:
# 'o'

# %%
nome[0:5]
# Out:
# 'Bruno'

# %%
nome[:5]
# Out:
# 'Bruno'

# %%
nome[6:]
# Out:
# 'Santos Lindoso'

# %%
nome[0:5:2]
# Out:
# 'Buo'

# %%
nome[:]
# Out:
# 'Bruno Santos Lindoso'

# %%
nome[::-1]
# Out:
# 'osodniL sotnaS onurB'
