# %% [markdown]
# # Manipulação de Strings

# %% [markdown]
# ## Maiúsculas, minúsculas e primeira letra maiúscula

# %%
curso = "pYtHOn"

# %%
curso.upper()
# Out:
# 'PYTHON'

# %%
curso.lower()
# Out:
# 'python'

# %%
curso.title()
# Out:
# 'Python'

# %% [markdown]
# ## Espaços em branco

# %%
curso = "    Python  "

# %%
curso.strip()
# Out:
# 'Python'

# %%
curso.lstrip()
# Out:
# 'Python  '

# %%
curso.rstrip()
# Out:
# '    Python'

# %% [markdown]
# ## Junções e centralizar

# %%
curso = "Python"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 curso = "Python"
# ----> 2 curso.append("!")
#       3 curso
#
# AttributeError: 'str' object has no attribute 'append'

# %%
curso.center(16, "#")
# Out:
# '#####Python#####'

# %%
".".join(curso)
# Out:
# 'P.y.t.h.o.n'
