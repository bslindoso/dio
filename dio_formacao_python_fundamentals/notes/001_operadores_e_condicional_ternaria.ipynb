# %% [markdown]
# # Input e Print

# %%
print(f"Hello World") # Para dar sorte aos estudos

nome = (input("Digite seu primeiro nome: " ))
sobrenome = (input("Digite seu sobrenome: " ))
print("Oi", nome, sobrenome, sep=" ", end="!")
# Out:
# Hello World
# Oi Bruno Lindoso!

# %% [markdown]
# # Operadores de Identidade
#
# São operadores utilizados para comparar se os dois objetos testados ocupam a mesma posição na memória.

# %%
curso = "Curso de Python"
nome_curso = curso
nome_outro_curso = "Curso de Python"
saldo, limite = 200, 200
saldo_1, limite_1 = 200, 1000

# %%
curso is nome_curso
# Out:
# True

# %%
curso is nome_outro_curso
# Out:
# False

# %%
curso is not nome_curso
# Out:
# False

# %%
saldo is limite
# Out:
# True

# %%
saldo_1 is limite_1
# Out:
# False

# %% [markdown]
# # Operadores de associação
#
# São operadores utilizados para verificar se um objeto está presente em uma sequência

# %%
curso = "Curso de Python"
frutas = ["laranja", "uva", "limão"]
saques = [1500, 100]

# %%
"Python" in curso
# Out:
# True

# %%
"maçã" not in frutas
# Out:
# True

# %%
200 in saques
# Out:
# False

# %% [markdown]
# # Condicional ternária

# %%
def tem_saldo(saldo:float):
  return "Saldo positivo" if saldo > 0 else "Saldo negativo"

# %%
tem_saldo(50.5)
# Out:
# 'Saldo positivo'

# %%
tem_saldo(-12)
# Out:
# 'Saldo negativo'
